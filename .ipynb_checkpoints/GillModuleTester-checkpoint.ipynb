# %%
import numpy as np
import matplotlib.pyplot as plt
import gill

# %%
#re-import gill for any new changes
import importlib
importlib.reload(gill)
# Out:
# <module 'gill' from '/home/russotto/projects/GillFromAdam/gill.py'>

# %%
gill.main_default()
# Out:
# /home/russotto/miniconda3/envs/pangeo/lib/python3.6/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:133: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   SparseEfficiencyWarning)
# /home/russotto/miniconda3/envs/pangeo/lib/python3.6/site-packages/matplotlib/contour.py:1173: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %%
#OK, that works! Now can play with non-default inputs:
gill.main_default(flipsign=True) #Initial perturbation negative sign. 
#Appears exactly flipped including velocity (contours weren't symmetric)
# Out:
# /home/russotto/miniconda3/envs/pangeo/lib/python3.6/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:133: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   SparseEfficiencyWarning)
# /home/russotto/miniconda3/envs/pangeo/lib/python3.6/site-packages/matplotlib/contour.py:1173: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %%
gill.main_default(x0=5) #shift the heat source location
# Out:
# /home/russotto/miniconda3/envs/pangeo/lib/python3.6/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:133: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   SparseEfficiencyWarning)
# /home/russotto/miniconda3/envs/pangeo/lib/python3.6/site-packages/matplotlib/contour.py:1173: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %%
gill.main_default(y0=1)
# Out:
# /home/russotto/miniconda3/envs/pangeo/lib/python3.6/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:133: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   SparseEfficiencyWarning)
# /home/russotto/miniconda3/envs/pangeo/lib/python3.6/site-packages/matplotlib/contour.py:1173: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %%
#Derivatives are additive, so for TRACMIP I could use a sum of individual 
#Gaussians and it should still be linear.

# %%
#Conditions used in Biasutti et al. (2009):
gill.main_default(y0=1, sx=1, sy=0.2, ymin=-1, xmin=-6, xmax=6, cphimax=.5)
# Out:
# /home/russotto/miniconda3/envs/pangeo/lib/python3.6/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:133: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   SparseEfficiencyWarning)
# /home/russotto/miniconda3/envs/pangeo/lib/python3.6/site-packages/matplotlib/contour.py:1173: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %%
#OK, this certainly looks like what's in the paper, though I think they should've
#had an indication of the contour intervals.
